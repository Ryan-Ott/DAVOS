# %%
# # Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install numpy

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Load the .pt file
image_tensor = torch.load('../../data/saved_results/original/2007_000033.pt')

# Convert the image tensor to a numpy array
image_array = image_tensor.numpy().transpose(1, 2, 0)

# Show the image
plt.imshow(image_array)
plt.show()

# %%
# Load the .pt file
image_tensor = torch.load('../../data/saved_results/maskclip/2007_000033.pt')

# Convert the image tensor to a numpy array
image_array = image_tensor.numpy().transpose(1, 2, 0)

# Show the image
plt.imshow(image_array)
plt.show()
